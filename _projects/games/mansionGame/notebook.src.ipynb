# %% [markdown]
# ---
# layout: post
# title: Mansion Game
# description: Explore the spooky mansion!
# permalink: /gamify/mansionGame
# author: Original Authors
# ---

# %%
# %%js
# import Core from '@assets/js/GameEnginev1.1/essentials/Game.js';
# import GameControl from '@assets/js/GameEnginev1.1/essentials/GameControl.js';
# import GameLevelMain from '@assets/js/projects/mansionGame/levels/mansionLevelMain.js';
# import GameLevel1 from '@assets/js/projects/mansionGame/levels/mansionLevel1.js';
# import GameLevel2 from '@assets/js/projects/mansionGame/levels/mansionLevel2.js';
# import GameLevel3 from '@assets/js/projects/mansionGame/levels/mansionLevel3.js';
# import GameLevel4 from '@assets/js/projects/mansionGame/levels/mansionLevel4.js';
# import GameLevel5 from '@assets/js/projects/mansionGame/levels/mansionLevel5.js';
# import GameLevel6 from '@assets/js/projects/mansionGame/levels/mansionLevel6.js';
# // GAME_RUNNER: Mansion Game | hide_edit: true,  width: 100%, height: 600px
# export const gameLevelClasses = [GameLevelMain, GameLevel1, GameLevel2, GameLevel3, GameLevel4, GameLevel5, GameLevel6];
# export { GameControl };
# export const GameCore = {
#     main: function(env, control) {
#         let canvas = env.gameContainer.querySelector('#gameCanvas');
#         console.log('gameContainer attached:', document.body.contains(env.gameContainer)); if (!canvas) {
#             canvas = document.createElement('canvas');
#             canvas.id = 'gameCanvas';
#             env.gameContainer.appendChild(canvas);
#             console.log('Appended canvas. document.getElementById?', document.getElementById('gameCanvas'));
#         }
#         env.gameCanvas = canvas;
#         env.gameContainer = canvas.parentElement;
#         return Core.main(env, control);
#     }
# };
# export const globalBackgroundData = {
#     src: '{{site.baseurl}}/images/projects/mansionGame/mansion_outside_image.png',
#     mode: 'cover',
#     crossOrigin: 'anonymous'
# };
