# %% [markdown]
# ---
# layout: post
# title: Create Performance Task Concepts
# description: Converted the CollegeBoard pseudocode into JavaScript. Descriptions for CBPT concepts are also included.
# permalink: /cpts_js
# ---

# %% [markdown]
# ## Output
# Produces output visible to the user, such as strings, numbers, or variable numbers. Equivalent of DISPLAY() in CBPT Pseudocode.

# %%
# %%js
#
# // Code_Runner:
#
# const username = "Alice1234"
# const courseProgress = 67
#
# console.log("Username: " + username)
# console.log("Course Progress (%): " + courseProgress)
